# %% [markdown]
# ## AccelerateAI - Time Series Analysis and Forecasting
#
# ### Regression with ARIMA Errors ( ARIMAX)

# %%
import numpy as np
import pandas as pd

# %%
# US Macro dataset
# Percentage changes in quarterly personal consumption expenditure, personal disposable income, 
# production, savings and the unemployment rate for the US, 1960 to 2016.

from sktime.datasets import load_uschange
y, X = load_uschange()

# %%
X.head()
# Out:
#      Income  Production   Savings  Unemployment
# 0  0.972261   -2.452700  4.810312           0.9
# 1  1.169085   -0.551525  7.287992           0.5
# 2  1.553271   -0.358708  7.289013           0.5
# 3 -0.255272   -2.185455  0.985230           0.7
# 4  1.987154    1.909734  3.657771          -0.1

# %%
y.plot(title="US Consumption(quarterly)");
